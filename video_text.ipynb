# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul8c/video_frames_info/blob/master/video_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr

# %%
# !pip install pytesseract

# %%
# !pip install Wand

# %%
# !apt-get install libmagickwand-dev

# %%
import PIL.Image
import pytesseract
from wand.image import Image as Img
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import numpy as np

import os
import cv2

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-65103e00-5b26-436a-a6dc-b5f0ff203236" name="files[]" multiple disabled />
#      <output id="result-65103e00-5b26-436a-a6dc-b5f0ff203236">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test1.mp4 to Test1.mp4

# %%
if not os.path.exists('image_frames'):
      os.makedirs('image_frames')

# %%
tvi = cv2.VideoCapture('Test1.mp4')

index = 0
while  tvi.isOpened():
      ret,frame = tvi.read()
      if not ret:
         break
      name = '/content/image_frames/frame'+ str(index) +'.jpg'

      print('Extracing frames....' + name)
      cv2.imwrite(name, frame)
      index = index + 1
      if cv2.waitKey(20) & 0xFF == ord('q'):
       break
       
tvi.release()
cv2.destroyAllWindows()
# Out:
# Extracing frames..../content/image_frames/frame0.jpg
# Extracing frames..../content/image_frames/frame1.jpg
# Extracing frames..../content/image_frames/frame2.jpg
# Extracing frames..../content/image_frames/frame3.jpg
# Extracing frames..../content/image_frames/frame4.jpg
# Extracing frames..../content/image_frames/frame5.jpg
# Extracing frames..../content/image_frames/frame6.jpg
# Extracing frames..../content/image_frames/frame7.jpg
# Extracing frames..../content/image_frames/frame8.jpg
# Extracing frames..../content/image_frames/frame9.jpg
# Extracing frames..../content/image_frames/frame10.jpg
# Extracing frames..../content/image_frames/frame11.jpg
# Extracing frames..../content/image_frames/frame12.jpg
# Extracing frames..../content/image_frames/frame13.jpg
# Extracing frames..../content/image_frames/frame14.jpg
# Extracing frames..../content/image_frames/frame15.jpg
# Extracing frames..../content/image_frames/frame16.jpg
# Extracing frames..../content/image_frames/frame17.jpg
# ...

# %%
from IPython.display import Image
Image('/content/image_frames/frame480.jpg',width=500,height=400)

# %%
im = PIL.Image.open('/content/image_frames/frame480.jpg').convert('L')
im = im.crop((550, 450, 1500, 580))
im.save('/content/image_frames/i480.jpg')

# %%
mage1 = cv2.imread('/content/image_frames/i480.jpg')
gray = cv2.cvtColor(mage1, cv2.COLOR_BGR2GRAY)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=950x130 at 0x7FC3CB155198>

# %%
imgp = PIL.Image.open('/content/image_frames/i480.jpg')
extractedInformation = pytesseract.image_to_string(imgp, lang='eng')

# %%
print(extractedInformation)
# Out:
# MP.09.CD.2238 |
